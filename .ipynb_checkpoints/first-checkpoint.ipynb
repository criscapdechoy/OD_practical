# %%
# !/usr/bin/python3
import pandas as pd
import os
import json
import csv
import sys
from pandas import json_normalize
import requests as r
import xmltodict
import time
import json
from datetime import datetime
import string 
import requests
from tenacity import *
from matplotlib import pyplot as plt
import semanticscholar as sch
from unittest import TestCase

# %%
API_URL = 'http://api.semanticscholar.org/v1'

def paper(id, include_unknown_references=False) -> dict:
    
    '''Paper lookup
    :param id: S2PaperId, DOI or ArXivId.
    :param include_unknown_references : bool, (optional) include non referenced paper.
    :returns: paper data or empty :class:`dict` if not found.
    :rtype: :class:`dict`
    '''
    
    data = __get_data('paper', id, include_unknown_references)
    
    return data

def author(id) -> dict:

    '''Author lookup
    :param id: S2AuthorId.
    :returns: author data or empty :class:`dict` if not found.
    :rtype: :class:`dict`
    '''

    data = __get_data('author', id)

    return data

@retry(
    wait=wait_fixed(30),
    retry=retry_if_exception_type(ConnectionRefusedError),
    stop=stop_after_attempt(10)
    )
def __get_data(method, id, include_unknown_references=False) -> dict:

    '''Get data from Semantic Scholar API
    :param method: 'paper' or 'author'.
    :param id: :class:`str`.
    :returns: data or empty :class:`dict` if not found.
    :rtype: :class:`dict`
    '''

    data = {}

    method_types = ['paper','author']
    if method not in method_types:
        raise ValueError('Invalid method type. Expected one of: {}'.format(method_types))

    url = '{}/{}/{}'.format(API_URL, method, id)
    if include_unknown_references:
        url += '?include_unknown_references=true'
    r = requests.get(url)
    
    if r.status_code == 200:
        data = r.json()
        if len(data) == 1 and 'error' in data:
            data = {}
    elif r.status_code == 429:
        raise ConnectionRefusedError('HTTP status 429 Too Many Requests.')

    return data

# %%
def test_paper():
    data = sch.paper('10.1093/mind/lix.236.433')
    assert data['title'] == 'Computing Machinery and Intelligence'
    
def test_author():
    data = sch.author(2262347)
    assert data['name'] == 'Alan M. Turing'

def test_not_found():
    data = sch.paper(0)
    assert len(data) == 0

# %%
data.keys()
# Out:
# dict_keys(['aliases', 'authorId', 'influentialCitationCount', 'name', 'papers', 'url'])

# %%
import xmltodict
import time
import json
import string
from bio import Entrez

from .. import constants as c
from ..find_tags import add_result_tags
from datetime import datetime
from ..find_tags import add_result_tags

Entrez.email = c.pubmed.ENTREZ_EMAIL


'''Translate function looks at the dictionary placed in constants/webpage.py and pass the query to the syntax of
the webpage'''


def translate(factorized_query):
    translation_dic = c.pubmed.TRANSLATION_DIC
    for key in translation_dic.keys():
        new_query = factorized_query.replace(key, translation_dic[key])
        factorized_query = new_query

    words_and_syms = factorized_query.split(' ')
    final_query = ''
    for word_or_sym in words_and_syms:
        if '[' in word_or_sym:
            try:
                word, field = word_or_sym.split('[')
                new_field = '[' + field
                if new_field not in translation_dic.values():
                    new_field = ''
                final_query += word + new_field + ' '
            except:
                final_query += word_or_sym + ' '
        else:
            final_query += word_or_sym + ' '


    return final_query


'''For every result in the search, we take title, authors, date, publication journal and url.'''


def search_pubmed(factorized_query, factorized_query_soft, results_by_source, sort_by):

    if not results_by_source:
        results_by_source = 100
    elif results_by_source:
        results_by_source = min(100, results_by_source)
    # Pass the query to the clinical trials format
    final_query = translate(factorized_query)
    # Get ids

    if sort_by == 'date':
        sort_parameter = 'most+recent' # coincides with the results shown in pubmed with order by most recent
    elif sort_by == 'author':
        sort_parameter = 'author' # coincides with the results shown in pubmed with order by first author
    elif sort_by == 'journal':
        sort_parameter = 'journal' # coincides with the results shown in pubmed with order by journal
    else:
        sort_parameter = 'relevance' # does not coincide with the results shown in pubmed with order by best match

    handle = Entrez.esearch(db="pubmed", term=final_query, sort=sort_parameter, retmax=results_by_source, api_key=c.pubmed.KEY)

    record = Entrez.read(handle)
    handle.close()

    id_list = record['IdList']
    number_of_results = str(record['Count'])

    if len(id_list) == 0:
        return {'results': [], 'number_of_results': '0'}

    # Get detailed info including Abstract
    handle = Entrez.efetch(db="pubmed", id=';'.join(id_list), retmode='xml', rettype="abstract", api_key=c.pubmed.KEY)

    s = handle.read()

    articles_list = json.loads(json.dumps(xmltodict.parse(s))).get("PubmedArticleSet", []).get("PubmedArticle", [])

    if len(id_list) == 1:
        articles_list = [articles_list]

    returned_list = list()
    T = 0

    count = 1001

    for article in articles_list:
        result_id = 'PUB' + str(count)[1:]
        count += 1

        title = article['MedlineCitation']['Article']['ArticleTitle']
        if type(title) == dict:

            try:
                intro = title['i'] + ' '
            except:
                intro = ''

            try:
                title = intro + title['#text']
            except:
                title = title['#text']

        if title:
            if title[-1] == '.':
                title = title[:-1]

        try:
            authors = article['MedlineCitation']['Article']['AuthorList']['Author']
            authors_list = list()

            if type(authors) is not list:
                authors = [authors]
            # TODO: Collective authors: maybe better to take collective name?
            for author in authors:
                try:
                    authors_list.append(author['ForeName'] + ' ' + author['LastName'])
                except:
                    # Here: Only Enters When Collective Name
                    pass
            authors = ', '.join(authors_list)
        except:
            authors = ''
            authors_list = []

        abstract = ''
        try:
            if type(article['MedlineCitation']['Article']['Abstract']['AbstractText']) is str:
                abstract += article['MedlineCitation']['Article']['Abstract']['AbstractText']
            elif type(article['MedlineCitation']['Article']['Abstract']['AbstractText']) is dict:
                if '@Label' in article['MedlineCitation']['Article']['Abstract']['AbstractText']:
                    abstract += article['MedlineCitation']['Article']['Abstract']['AbstractText']['@Label'] + ': '
                abstract += article['MedlineCitation']['Article']['Abstract']['AbstractText']['#text']
            elif type(article['MedlineCitation']['Article']['Abstract']['AbstractText']) is list:
                for field in article['MedlineCitation']['Article']['Abstract']['AbstractText']:
                    if '@Label' in field.keys():
                        abstract += field['@Label'] + ': '
                    abstract += field['#text'] + '\n'
            else:
                abstract = 'Unknown abstract'

        except:
            abstract = 'Unknown abstract'

        try:
            date = article['MedlineCitation']['Article']['ArticleDate']
            date_str = str(date['Year'] + '-' + date['Month'] + '-' + date['Day'])
            printing_date = date_str
            date_object = datetime.strptime(date_str, "%Y-%M-%d")
        except:
            try:
                date = article['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']
                date_str = str(date['Year'] + '-' + date['Month'] + '-' + date['Day'])
                printing_date = date_str
                date_object = datetime.strptime(date_str, "%Y-%M-%D")
            except:
                try:
                    date = article['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']
                    date_str = str(date['Year'] + '-' + date['Month'])
                    printing_date = date_str
                    date_object = datetime.strptime(date_str, "%Y-%M")
                except:
                    try:
                        date = article['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']
                        date_str = str(date['Year'])
                        printing_date = date_str
                        date_object = datetime.strptime(date_str, "%Y")
                    except:
                        try:
                            date = article['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['MedlineDate']
                            try:
                                year_index = date.find('20')
                            except:
                                year_index = date.find('19')
                            date_str = str(date)[year_index:year_index+4]
                            printing_date = date_str
                            date_object = datetime.strptime(date_str, "%Y")
                        except:
                            printing_date = 'Unknown'
                            date = '1000'
                            date_object = datetime.strptime(date, "%Y")

        url = article['PubmedData']['ArticleIdList']['ArticleId']
        if type(url) is not list:
            url = [url]

        try:
            journal = article['MedlineCitation']['Article']['Journal']['Title']
        except:
            journal = ''

        try:
            keywords = list()
            keyword_list = elem['MedlineCitation']['KeywordList']['Keyword']
            for elem in keyword_list:
                keywords.append(elem['#text'])

        except:
            keywords = ['']

        returned_list.append(
            {
                'result_id': result_id,
                'title': title,
                'authors': authors,
                'abstract': abstract,
                'date': date_object.strftime("%Y-%m-%d"),
                'printing_date': printing_date,
                'publication_journal': journal,
                'url': c.pubmed.URL + url[0]['#text'],
                'keywords': keywords,
                'type': 'articles',
                'hard_or_soft': 'publications'
            }
        )
        #print(keywords)
        #print('*'*60)

    #t1 = time.time()
    final_result_list = add_result_tags(returned_list, 'pubmed')
    #t2 = time.time()
    #print('FINAL TIME, pubmed: ', t2 - t1)

    return {'results': final_result_list, 'number_of_results': number_of_results}
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-507a8536c32b> in <module>
#       3 import json
#       4 import string
# ----> 5 from bio import Entrez
#       6
#       7 from .. import constants as c
#
# ImportError: cannot import name 'Entrez' from 'bio' (/Users/cristinacapdevilachoy/Documents/Git/OD_practical/env/lib/python3.7/site-packages/bio/__init__.py)

# %%
final_query = 'breast'

results_by_source = 200

url = 'http://export.arxiv.org/api/query?search_query='

#Call the API specifying the desired number of results
sort_parameter = 'lastUpdatedDate'
## 'lastUpdatedDate','submittedDate', 'relevance'

response = r.get(
    url + final_query + '&start=0&max_results=' + str(results_by_source) +
    '&sortBy='+str(sort_parameter)+'&sortOrder=descending'
)

# %%
d = json.loads(json.dumps(xmltodict.parse(response.text)))['feed']['entry']
number_of_results = json.loads(json.dumps(xmltodict.parse(response.text)))['feed']['opensearch:totalResults']['#text']

# %%
json_normalize(d)
# Out:
#                                     id               updated  \
# 0    http://arxiv.org/abs/2001.09282v2  2020-04-08T08:52:44Z
# 1    http://arxiv.org/abs/2004.03500v1  2020-04-07T15:53:26Z
# 2    http://arxiv.org/abs/2004.03037v1  2020-04-06T23:12:31Z
# 3    http://arxiv.org/abs/2004.01397v1  2020-04-03T06:49:31Z
# 4    http://arxiv.org/abs/2003.12248v2  2020-04-02T09:08:12Z
# ..                                 ...                   ...
# 195  http://arxiv.org/abs/1904.04520v1  2019-04-09T08:26:02Z
# 196  http://arxiv.org/abs/1804.10812v2  2019-04-07T16:54:51Z
# 197  http://arxiv.org/abs/1904.03517v1  2019-04-06T19:48:54Z
# 198  http://arxiv.org/abs/1904.07295v1  2019-04-05T14:10:54Z
# 199  http://arxiv.org/abs/1904.01832v1  2019-04-03T08:18:09Z
#
#                 published                                              title  \
# 0    2020-01-25T09:13:39Z  Limited Angle Tomography reconstruction for no...
# 1    2020-04-07T15:53:26Z  BreastScreening: On the Use of Multi-Modality ...
# 2    2020-04-06T23:12:31Z  Dense Steerable Filter CNNs for Exploiting Rot...
# 3    2020-04-03T06:49:31Z  Crossover-Net: Leveraging the Vertical-Horizon...
# 4    2020-03-27T06:09:13Z  Dark-field signal extraction in propagation-ba...
# ..                    ...                                                ...
# 195  2019-04-09T08:26:02Z  Regression Concept Vectors for Bidirectional E...
# 196  2018-04-28T14:57:53Z  Imaging of Fiber-Like Structures in Digital Br...
# 197  2019-04-06T19:48:54Z  Nonparametric tests for transition probabiliti...
# 198  2019-04-05T14:10:54Z  The population-attributable fraction for time-...
# 199  2019-04-03T08:18:09Z  Bayesian Pharmacokinetic Modeling of Dynamic C...
#
#                                                summary  \
# 0    The purpose of the present work is the study o...
# 1    This paper describes the field research, desig...
# 2    Histology images are inherently symmetric unde...
# 3    Robust segmentation for non-elongated tissues ...
# 4    A method for extracting the dark-field signal ...
# ..                                                 ...
# 195  Explanations for deep neural network predictio...
# 196  Fiber-like features are an important aspect of...
# 197  This paper proposes nonparametric two-sample t...
# 198  The public health impact of a harmful exposure...
# 199  Tracer-kinetic analysis of dynamic contrast-en...
#
#                                                 author  \
# 0    [{'name': 'G. E. Poma'}, {'name': 'F. Garibald...
# 1    [{'name': 'Francisco Maria Calisto'}, {'name':...
# 2    [{'name': 'Simon Graham'}, {'name': 'David Eps...
# 3    [{'name': 'Qian Yu'}, {'name': 'Yinghuan Shi'}...
# 4    [{'name': 'T. E. Gureyev'}, {'name': 'D. M. Pa...
# ..                                                 ...
# 195  [{'name': 'Mara Graziani'}, {'name': 'Vincent ...
# 196  [{'name': 'Sean D. Rose'}, {'name': 'Emil Y. S...
# 197                                                NaN
# 198  [{'name': 'Maja von Cube'}, {'name': 'Martin S...
# 199  [{'name': 'Andreas Mittermeier'}, {'name': 'Bi...
#
#                                                   link  \
# 0    [{'@title': 'doi', '@href': 'http://dx.doi.org...
# 1    [{'@href': 'http://arxiv.org/abs/2004.03500v1'...
# 2    [{'@href': 'http://arxiv.org/abs/2004.03037v1'...
# 3    [{'@href': 'http://arxiv.org/abs/2004.01397v1'...
# 4    [{'@href': 'http://arxiv.org/abs/2003.12248v2'...
# ..                                                 ...
# 195  [{'@href': 'http://arxiv.org/abs/1904.04520v1'...
# 196  [{'@title': 'doi', '@href': 'http://dx.doi.org...
# 197  [{'@title': 'doi', '@href': 'http://dx.doi.org...
# 198  [{'@title': 'doi', '@href': 'http://dx.doi.org...
# 199  [{'@title': 'doi', '@href': 'http://dx.doi.org...
#
#                                               category  \
# 0    [{'@term': 'physics.med-ph', '@scheme': 'http:...
# 1    [{'@term': 'cs.HC', '@scheme': 'http://arxiv.o...
# 2    [{'@term': 'eess.IV', '@scheme': 'http://arxiv...
# 3    [{'@term': 'eess.IV', '@scheme': 'http://arxiv...
# 4    [{'@term': 'physics.med-ph', '@scheme': 'http:...
# ..                                                 ...
# 195  [{'@term': 'cs.LG', '@scheme': 'http://arxiv.o...
# 196                                                NaN
# 197                                                NaN
# 198  [{'@term': 'stat.AP', '@scheme': 'http://arxiv...
# 199  [{'@term': 'physics.med-ph', '@scheme': 'http:...
#
#             arxiv:doi.@xmlns:arxiv                 arxiv:doi.#text  \
# 0    http://arxiv.org/schemas/atom  10.1088/1748-0221/15/04/C04019
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ..                             ...                             ...
# 195                            NaN                             NaN
# 196  http://arxiv.org/schemas/atom        10.1117/1.JMI.6.3.031404
# 197  http://arxiv.org/schemas/atom   10.1080/10485252.2019.1705298
# 198  http://arxiv.org/schemas/atom          10.1002/bimj.201800252
# 199  http://arxiv.org/schemas/atom        10.1088/1361-6560/ab3a5a
#
#         arxiv:comment.@xmlns:arxiv  \
# 0    http://arxiv.org/schemas/atom
# 1    http://arxiv.org/schemas/atom
# 2                              NaN
# 3    http://arxiv.org/schemas/atom
# 4                              NaN
# ..                             ...
# 195  http://arxiv.org/schemas/atom
# 196  http://arxiv.org/schemas/atom
# 197                            NaN
# 198  http://arxiv.org/schemas/atom
# 199  http://arxiv.org/schemas/atom
#
#                                    arxiv:comment.#text  \
# 0          10 pages, 10 figures, proceeding conference
# 1    AVI 2020 Short Papers, 5 pages, 2 figures, for...
# 2                                                  NaN
# 3                                 11 pages, 14 figures
# 4                                                  NaN
# ..                                                 ...
# 195                       9 pages, 3 figures, 3 tables
# 196  This version has been updated with changes mad...
# 197                                                NaN
# 198               A revised version has been submitted
# 199                                14 pages, 6 figures
#
#     arxiv:journal_ref.@xmlns:arxiv  \
# 0    http://arxiv.org/schemas/atom
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 195  http://arxiv.org/schemas/atom
# 196  http://arxiv.org/schemas/atom
# 197                            NaN
# 198  http://arxiv.org/schemas/atom
# 199                            NaN
#
#                                arxiv:journal_ref.#text  \
# 0           2020 IOP Publishing Ltd and Sissa Medialab
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195  Understanding and Interpreting Machine Learnin...
# 196    SPIE Journal of Medical Imaging 6 (2019) 031404
# 197                                                NaN
# 198                          Biometrical Journal, 2019
# 199                                                NaN
#
#     arxiv:primary_category.@xmlns:arxiv arxiv:primary_category.@term  \
# 0         http://arxiv.org/schemas/atom               physics.med-ph
# 1         http://arxiv.org/schemas/atom                        cs.HC
# 2         http://arxiv.org/schemas/atom                      eess.IV
# 3         http://arxiv.org/schemas/atom                      eess.IV
# 4         http://arxiv.org/schemas/atom               physics.med-ph
# ..                                  ...                          ...
# 195       http://arxiv.org/schemas/atom                        cs.LG
# 196       http://arxiv.org/schemas/atom               physics.med-ph
# 197       http://arxiv.org/schemas/atom                      stat.ME
# 198       http://arxiv.org/schemas/atom                      stat.AP
# 199       http://arxiv.org/schemas/atom               physics.med-ph
#
#     arxiv:primary_category.@scheme         author.name  category.@term  \
# 0    http://arxiv.org/schemas/atom                 NaN             NaN
# 1    http://arxiv.org/schemas/atom                 NaN             NaN
# 2    http://arxiv.org/schemas/atom                 NaN             NaN
# 3    http://arxiv.org/schemas/atom                 NaN             NaN
# 4    http://arxiv.org/schemas/atom                 NaN             NaN
# ..                             ...                 ...             ...
# 195  http://arxiv.org/schemas/atom                 NaN             NaN
# 196  http://arxiv.org/schemas/atom                 NaN  physics.med-ph
# 197  http://arxiv.org/schemas/atom  Giorgos Bakoyannis         stat.ME
# 198  http://arxiv.org/schemas/atom                 NaN             NaN
# 199  http://arxiv.org/schemas/atom                 NaN             NaN
#
#                   category.@scheme
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 195                            NaN
# 196  http://arxiv.org/schemas/atom
# 197  http://arxiv.org/schemas/atom
# 198                            NaN
# 199                            NaN
#
# [200 rows x 20 columns]

# %%
import requests as r
import xmltodict
import time
import json
from datetime import datetime
import string 


def search_arxiv(factorized_query, factorized_query_soft, results_by_source, sort_by):
    results_by_source = 200

    #Pass the factorized query to arxiv notation and call the API for the search
    final_query = translate(factorized_query)

    #Call the API specifying the desired number of results
    sort_parameter = 'lastUpdatedDate'
    ## 'lastUpdatedDate','submittedDate', 'relevance'

    response = r.get(
        c.arxiv.URL + final_query + '&start=0&max_results=' + str(results_by_source) +
        '&sortBy='+str(sort_parameter)+'&sortOrder=descending'
    )

    try:
        d = json.loads(json.dumps(xmltodict.parse(response.text)))['feed']['entry']
        number_of_results = json.loads(json.dumps(xmltodict.parse(response.text)))['feed']['opensearch:totalResults']['#text']
    except:
        return {'results': [], 'number_of_results': '0'}

    if type(d) is not list:
        d = [d]

    trials_list = list()

    count = 1001

    for trial in d:
        result_id = 'AXV' + str(count)[1:]
        count += 1

        try:
            title = trial['title']
        except:
            title = 'Unknown title'

        try:
            summary = trial['summary']
        except:
            summary = 'Unknown summary'

        try:
            authors_list = trial['author']
            authors = list()

            if type(authors_list) is not list:
                authors_list = [authors_list]

            for element in authors_list:
                authors.append(element['name'])

        except:
            authors = 'Unknown authors'

        try:
            printing_date = trial['published'].replace('T', ' ').replace('Z', '')
            date = trial['published'].replace('T', ' ').replace('Z', '')
            date_object = datetime.strptime(date, "%Y-%m-%d %X")

        except:
            printing_date = 'Unknown'
            date = 'January 1, 2000'
            date_object = datetime.strptime(date, "%B %d, %Y")

        try:
            url = trial['link'][0]['@href']
        except:
            url = ''

        trials_list.append(
            {
                'result_id': result_id,
                'title': title,
                'authors': ', '.join(authors),
                'abstract': summary,
                'printing_date': printing_date,
                'date': date_object.strftime("%Y-%m-%d %X"),
                'url': url,
                'type': 'trials',
                'hard_or_soft': 'hard'
            }
        )
    #t1 = time.time()
    final_result_list = add_result_tags(trials_list[:results_by_source], 'arxiv')
    #t2 = time.time()
    #print('FINAL TIME, arxiv: ', t2 - t1)

    return {'results': final_result_list, 'number_of_results': number_of_results}

# %% [markdown]
# ## Definitive

# %%
# Global variables to control script flow
input_default_path = "data/breastcancer.json"
tmp_path = "tmp"

# %%
inputdir = input_default_path
# Assign output file for output CSV
if not os.path.exists(tmp_path):
    os.makedirs(tmp_path)
    print(f"[INFO] Created a new folder {tmp_path}")
# Evaluation output file config
head, tail = os.path.split(inputdir)
tail = '.'.join((tail.split('.')[0], 'csv'))
outputfile = f"{head}/{tail}"
print(outputfile)
if os.path.exists(outputfile):
    os.remove(outputfile)
    print(f"{outputfile} file removed")
# Out:
# data/breastcancer.csv
# data/breastcancer.csv file removed

# %%
node = 'result'
json_file_path = inputdir
csv_file_path = outputfile

fp = open(json_file_path, 'r')
json_value = fp.read()
raw_data = json.loads(json_value)
fp.close()

data_to_be_processed = raw_data[node]['hits']['hit']
df = json_normalize(data_to_be_processed, max_level=2)
for i in range(len(df)):
    if type(df['info.authors.author'][i]) != type(list()):
        df['info.authors.author'][i] = [df['info.authors.author'][i]]

# %%
df = df.rename(columns={"@score":"score","@id":"id","url":"url_num","info.authors.author":"author","info.title":"title",
                   "info.year":"year","info.type":"pub_type","info.key":"key","info.ee":"ee","info.url":"url",
                   "info.venue":"venue","info.volume":"vol","info.number":"num","info.pages":"pages",
                   "info.doi":"doi", "info.publisher":"publisher"
                   })

# %%
df = df[df['doi'].notna()]

# %%
data['topics'][0]
# Out:
# {'topic': 'Deep learning',
#  'topicId': '2762',
#  'url': 'https://www.semanticscholar.org/topic/2762'}

# %%
bool({})
# Out:
# False

# %%
i = 0
new = []
to_drop = []
for row in df['doi'][:500]:
    i += 1
    data = sch.paper(row)
    print(row,bool(data))
    if data:
        new_topics = []
        for topic in data['topics']:
            new_topics.append([row, topic['topicId'],topic['topic']])
        new.append(new_topics)
    else:
        to_drop.append(i)
# Out:
# 10.1186/S12880-018-0303-3 False
# 10.1109/TBME.2018.2887083 True
# 10.1007/978-3-030-30443-0_10 True
# 10.1109/CISP-BMEI.2017.8301908 True
# 10.1016/J.CMPB.2015.11.010 False
# 10.1109/BHI.2014.6864395 True
# 10.1145/2598394.2609853 True
# 10.1145/2464576.2466809 True
# 10.2200/S00325ED1V01Y201012BME039 True
# 10.1145/2001858.2002040 True
# 10.1016/J.FUTURE.2019.01.033 False
# 10.1016/J.IJMEDINF.2019.03.004 False
# 10.1016/J.NEUCOM.2018.03.072 False
# 10.1016/J.JBI.2019.103180 False
# 10.1186/S12911-019-0873-1 False
# 10.1109/TMI.2018.2870343 True
# 10.1007/S00371-017-1447-9 False
# 10.1145/3307339.3342164 True
# 10.1109/EMBC.2019.8856744 True
# 10.1109/ISBI.2019.8759205 True
# 10.1117/12.2513561 True
# 10.1117/12.2512943 True
# 10.1186/S12918-018-0530-9 False
# 10.1016/J.CMPB.2017.10.016 False
# 10.1504/IJMEI.2018.10014081 True
# 10.1109/TBME.2017.2695103 True
# 10.1109/BIBM.2018.8621315 True
# 10.1117/12.2318324 True
# 10.1117/12.2317675 True
# 10.1117/12.2293644 True
# 10.1117/12.2293412 True
# 10.3233/978-1-61499-852-5-661 True
# 10.1117/12.2293307 True
# 10.1186/S12918-017-0445-X False
# 10.1007/S10278-016-9922-9 False
# 10.1109/ICEEE.2017.8108865 True
# 10.1117/12.2254516 True
# 10.1117/12.2254630 True
# 10.1117/12.2254506 True
# 10.1142/S0219720016440029 True
# 10.1109/EMBC.2016.7590885 True
# 10.1007/978-3-319-41546-8_8 True
# 10.1109/EMBC.2015.7318974 True
# 10.1109/ISDA.2015.7489216 True
# 10.1117/12.2082466 True
# 10.1186/S12880-014-0041-0 False
# 10.1007/S11548-014-0976-1 False
# 10.1111/J.1468-0394.2012.00654.X False
# 10.1504/IJMEI.2014.058532 True
# 10.1186/1472-6947-14-24 True

# %%
len(to_drop)
# Out:
# 707

# %%
df.to_csv(outputfile)

# %%
any([i!=np.nan for i in df['info.publisher']])
# Out:
# True

# %%
group = 'pub_type'
types = df.groupby(group)
#plt.bar(np.arange(len(types)),types.count().iloc[:,0])
#plt.title(group)
types.groups
# Out:
# {'Books and Theses': Int64Index([  0,  10,  12,  43,  44,  45,  46,  47,  55,  56,  67,  68,  81,
#               82,  89, 140, 427, 428, 429, 716],
#             dtype='int64'),
#  'Conference and Workshop Papers': Int64Index([  3,   5,   7,   8,   9,  11,  13,  21,  22,  23,
#              ...
#              893, 894, 895, 896, 897, 898, 996, 997, 998, 999],
#             dtype='int64', length=459),
#  'Informal Publications': Int64Index([  4,  27,  28,  29,  30,  42,  61, 138, 139, 396, 397, 398, 399,
#              400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412,
#              413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425,
#              426, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 693,
#              694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706,
#              707, 708, 709, 710, 711, 712, 713, 714, 715, 899, 900, 901, 902,
#              903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915,
#              916],
#             dtype='int64'),
#  'Journal Articles': Int64Index([  1,   2,   6,  14,  15,  16,  17,  18,  19,  20,
#              ...
#              986, 987, 988, 989, 990, 991, 992, 993, 994, 995],
#             dtype='int64', length=427),
#  'Parts in Books or Collections': Int64Index([106, 395], dtype='int64')}

# %%
# Convert to string keeping encoding in mind...
def to_string(s):
    try:
        return str(s)
    except:
        # Change the encoding type if needed
        return s.encode('utf-8')

# %%
def reduce_item(key, value):
    global reduced_item

    # Reduction Condition 1
    if type(value) is list:
        i = 0
        for sub_item in value:
            reduce_item(key + '_' + to_string(i), sub_item)
            i = i + 1

    # Reduction Condition 2
    elif type(value) is dict:
        sub_keys = value.keys()
        for sub_key in sub_keys:
            reduce_item(key + '_' + to_string(sub_key), value[sub_key])

    # Base Condition
    else:
        reduced_item[to_string(key)] = to_string(value)

# %%
    node = 'result'
    json_file_path = inputdir
    csv_file_path = outputfile

    fp = open(json_file_path, 'r')
    json_value = fp.read()
    raw_data = json.loads(json_value)
    fp.close()

    data_to_be_processed = raw_data[node]['hits']

# %%
import json
from pandas.io.json import json_normalize
import argparse


def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x
    flatten(y)
    return out

# %%
import io
from pandas.io.json import json_normalize



df = pd.concat([pd.DataFrame(data_to_be_processed), 
                json_normalize(data_to_be_processed['nested_array_to_expand'])], 
                axis=1).drop('nested_array_to_expand', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b5b820c3734c> in <module>
#       5
#       6 df = pd.concat([pd.DataFrame(data_to_be_processed),
# ----> 7                 json_normalize(data_to_be_processed['nested_array_to_expand'])],
#       8                 axis=1).drop('nested_array_to_expand', 1)
#
# KeyError: 'nested_array_to_expand'

# %%
final_data
# Out:
#          @id @score info_authors_author_0_@pid   info_authors_author_0_text  \
# 0     388703      5                        NaN                          NaN
# 1      59140      4                   235/2149               Yoo Kyung Yeom
# 2     159453      4                     89/494                    Hang Song
# 3     271032      4                   249/6174         Zbigniew Leszczynski
# 4     348056      4                   239/5091                       Han Le
# 5     878013      4                    30/7002                 Dongdong Sun
# 6    1077541      4                    00/9498           Maria João Cardoso
# 7    1768787      4                    90/9502             Verónica Burriel
# 8    1805847      4          w/StephanMWinkler           Stephan M. Winkler
# 9    2082384      4          w/StephanMWinkler           Stephan M. Winkler
# 10   2204726      4                        NaN                          NaN
# 11   2313708      4                    71/3941                Fulvio Casali
# 12   2462011      4                    18/1119               Denise Guliato
# 13   2595928      4          w/StephanMWinkler           Stephan M. Winkler
# 14     82915      3                   234/5392              Sana Ullah Khan
# 15     96751      3                   238/3496  Olaf Johan Hartmann-Johnsen
# 16     97997      3                    73/1810                     Yang Guo
# 17    108623      3                   238/1216          Sepideh Shamsizadeh
# 18    125541      3                   247/5863      Jacqueline A. ter Stege
# 19    171060      3                   182/3518               Ravi K. Samala
# 20    177881      3                   183/7178           Dayakshini Sathish
# 21    193472      3                   155/7709              Priyanka Gandhi
# 22    196437      3                   229/8990            Redona Brahimetaj
# 23    219475      3                    75/2339                 Wenming Yang
# 24    271321      3                   201/7777                 Peter Naylor
# 25    285444      3                     73/772                Karen Drukker
# 26    285503      3                   239/2042               Giacomo Nebbia
# 27    330425      3                   234/8847                Albee Y. Ling
# 28    336372      3                   238/1216          Sepideh Shamsizadeh
# 29    373651      3                   239/2114          Suzanne C. Wetstein
# ..       ...    ...                        ...                          ...
# 970  1121600      2                    23/5241                      Jun Fan
# 971  1121887      2                   175/2871                    Joana Diz
# 972  1122050      2                   153/3232               Satya P. Singh
# 973  1123128      2                    33/3738                  Jinn-Yi Yeh
# 974  1127540      2                   179/6184               Gabriele Magna
# 975  1129184      2                   122/3986                  Turgay Ayer
# 976  1129466      2                   149/0349             S. Aytaç Korkmaz
# 977  1130174      2                   192/0117                   Shama Alam
# 978  1130230      2                   153/5370                   Soobok Joe
# 979  1130250      2                   192/0124          Mario Lozano-Lozano
# 980  1138738      2                   215/3716                    Wanli You
# 981  1139503      2                   173/3743            Rozita Rastghalam
# 982  1141575      2                   196/9854              Alexis Gallegos
# 983  1146530      2                   188/6873   Muhammad Azhar Hayat Nawaz
# 984  1149557      2                    59/8061                     Pin Wang
# 985  1150897      2                   55/10132         Mahmoud Reza Saybani
# 986  1155163      2                   181/8332             Fabio A. Spanhol
# 987  1157487      2                   160/1577                    Qing Ping
# 988  1162486      2                   137/7963                   Linqi Song
# 989  1163769      2                   90/514-5                  Jun Xu 0005
# 990  1163771      2                   165/7751             Shadi Albarqouni
# 991  1163793      2                   133/7111          Martina T. Bevacqua
# 992  1163830      2                    64/4981            Mehrdad J. Gangeh
# 993  1163915      2                   05/10169             Mohammad Peikari
# 994  1164011      2                   140/7324                Ahmed M. Alaa
# 995  1169852      2                    00/9714              Michael J. Paul
# 996  1174004      2                  86/475-11                Hao Chen 0011
# 997  1178918      2                        NaN                          NaN
# 998  1180244      2                   175/9533              Burook Misganaw
# 999  1181468      2                   186/5693                Alex C. Cheng
#
#     info_authors_author_10_@pid info_authors_author_10_text  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                         02/99               Ashish Sharma
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                     247/6123       Eveline M. A. Bleiker
# 19                          NaN                         NaN
# 20                          NaN                         NaN
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                          NaN                         NaN
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                     182/2039            Laura C. Collins
# ..                          ...                         ...
# 970                         NaN                         NaN
# 971                         NaN                         NaN
# 972                         NaN                         NaN
# 973                         NaN                         NaN
# 974                         NaN                         NaN
# 975                         NaN                         NaN
# 976                         NaN                         NaN
# 977                         NaN                         NaN
# 978                         NaN                         NaN
# 979                         NaN                         NaN
# 980                         NaN                         NaN
# 981                         NaN                         NaN
# 982                         NaN                         NaN
# 983                         NaN                         NaN
# 984                         NaN                         NaN
# 985                         NaN                         NaN
# 986                         NaN                         NaN
# 987                         NaN                         NaN
# 988                         NaN                         NaN
# 989                         NaN                         NaN
# 990                         NaN                         NaN
# 991                         NaN                         NaN
# 992                         NaN                         NaN
# 993                         NaN                         NaN
# 994                         NaN                         NaN
# 995                         NaN                         NaN
# 996                         NaN                         NaN
# 997                         NaN                         NaN
# 998                         NaN                         NaN
# 999                         NaN                         NaN
#
#     info_authors_author_11_@pid info_authors_author_11_text  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                       82/3926                Erich Bremer
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
# 20                          NaN                         NaN
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                          NaN                         NaN
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                     151/2720           Stuart J. Schnitt
# ..                          ...                         ...
# 970                         NaN                         NaN
# 971                         NaN                         NaN
# 972                         NaN                         NaN
# 973                         NaN                         NaN
# 974                         NaN                         NaN
# 975                         NaN                         NaN
# 976                         NaN                         NaN
# 977                         NaN                         NaN
# 978                         NaN                         NaN
# 979                         NaN                         NaN
# 980                         NaN                         NaN
# 981                         NaN                         NaN
# 982                         NaN                         NaN
# 983                         NaN                         NaN
# 984                         NaN                         NaN
# 985                         NaN                         NaN
# 986                         NaN                         NaN
# 987                         NaN                         NaN
# 988                         NaN                         NaN
# 989                         NaN                         NaN
# 990                         NaN                         NaN
# 991                         NaN                         NaN
# 992                         NaN                         NaN
# 993                         NaN                         NaN
# 994                         NaN                         NaN
# 995                         NaN                         NaN
# 996                         NaN                         NaN
# 997                         NaN                         NaN
# 998                         NaN                         NaN
# 999                         NaN                         NaN
#
#     info_authors_author_12_@pid info_authors_author_12_text  ...  \
# 0                           NaN                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                       02/5135            Jonas S. Almeida  ...
# 5                           NaN                         NaN  ...
# 6                           NaN                         NaN  ...
# 7                           NaN                         NaN  ...
# 8                           NaN                         NaN  ...
# 9                           NaN                         NaN  ...
# 10                          NaN                         NaN  ...
# 11                          NaN                         NaN  ...
# 12                          NaN                         NaN  ...
# 13                          NaN                         NaN  ...
# 14                          NaN                         NaN  ...
# 15                          NaN                         NaN  ...
# 16                          NaN                         NaN  ...
# 17                          NaN                         NaN  ...
# 18                          NaN                         NaN  ...
# 19                          NaN                         NaN  ...
# 20                          NaN                         NaN  ...
# 21                          NaN                         NaN  ...
# 22                          NaN                         NaN  ...
# 23                          NaN                         NaN  ...
# 24                          NaN                         NaN  ...
# 25                          NaN                         NaN  ...
# 26                          NaN                         NaN  ...
# 27                          NaN                         NaN  ...
# 28                          NaN                         NaN  ...
# 29                      70/5175          Josien P. W. Pluim  ...
# ..                          ...                         ...  ...
# 970                         NaN                         NaN  ...
# 971                         NaN                         NaN  ...
# 972                         NaN                         NaN  ...
# 973                         NaN                         NaN  ...
# 974                         NaN                         NaN  ...
# 975                         NaN                         NaN  ...
# 976                         NaN                         NaN  ...
# 977                         NaN                         NaN  ...
# 978                         NaN                         NaN  ...
# 979                         NaN                         NaN  ...
# 980                         NaN                         NaN  ...
# 981                         NaN                         NaN  ...
# 982                         NaN                         NaN  ...
# 983                         NaN                         NaN  ...
# 984                         NaN                         NaN  ...
# 985                         NaN                         NaN  ...
# 986                         NaN                         NaN  ...
# 987                         NaN                         NaN  ...
# 988                         NaN                         NaN  ...
# 989                         NaN                         NaN  ...
# 990                         NaN                         NaN  ...
# 991                         NaN                         NaN  ...
# 992                         NaN                         NaN  ...
# 993                         NaN                         NaN  ...
# 994                         NaN                         NaN  ...
# 995                         NaN                         NaN  ...
# 996                         NaN                         NaN  ...
# 997                         NaN                         NaN  ...
# 998                         NaN                         NaN  ...
# 999                         NaN                         NaN  ...
#
#                        info_publisher  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12   Morgan &amp; Claypool Publishers
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ..                                ...
# 970                               NaN
# 971                               NaN
# 972                               NaN
# 973                               NaN
# 974                               NaN
# 975                               NaN
# 976                               NaN
# 977                               NaN
# 978                               NaN
# 979                               NaN
# 980                               NaN
# 981                               NaN
# 982                               NaN
# 983                               NaN
# 984                               NaN
# 985                               NaN
# 986                               NaN
# 987                               NaN
# 988                               NaN
# 989                               NaN
# 990                               NaN
# 991                               NaN
# 992                               NaN
# 993                               NaN
# 994                               NaN
# 995                               NaN
# 996                               NaN
# 997                               NaN
# 998                               NaN
# 999                               NaN
#
#                                             info_title  \
# 0    Bio-statistical approaches to evaluate the lin...
# 1    Screening mammography for second breast cancer...
# 2    Detectability of Breast Tumors in Excised Brea...
# 3    Artificial Neural Networks in Forecasting Canc...
# 4    Utilizing Automated Breast Cancer Detection to...
# 5    Prognosis prediction of human breast cancer by...
# 6    The breast cancer conservative treatment. Cosm...
# 7    Conceptual Schema of Breast Cancer - The backg...
# 8    Data based prediction of cancer diagnoses usin...
# 9    Evolutionary identification of cancer predicto...
# 10   Description et classification des masses mamma...
# 11   X-Report Breast - IT Tools to Early Detect Bre...
# 12   Modeling and Analysis of Shape with Applicatio...
# 13   Identification of cancer diagnosis estimation ...
# 14   An e-Health care services framework for the de...
# 15   Using clinical cancer registry data for estima...
# 16   Identification of cancer subtypes by integrati...
# 17   CAMIRADA - Cancer microRNA association discove...
# 18   The impact of an online patient decision aid f...
# 19   Breast Cancer Diagnosis in Digital Breast Tomo...
# 20   Role of normalization of breast thermogram ima...
# 21   Identifying Symptom Clusters in Breast Cancer ...
# 22   Computer Aided Detection and Diagnosis System ...
# 23   A Comprehensive Classification System for Brea...
# 24   Predicting Residual Cancer Burden In A Triple ...
# 25   Breast MRI radiomics for the pre-treatment pre...
# 26   Deep learning of sub-regional breast parenchym...
# 27   A Semi-Supervised Machine Learning Approach to...
# 28   CAMIRADA - Cancer microRNA association discove...
# 29   Deep learning assessment of breast terminal du...
# ..                                                 ...
# 970  Structure-Leveraged Methods in Breast Cancer R...
# 971  Applying Data Mining Techniques to Improve Bre...
# 972  An Improved CAD System for Breast Cancer Diagn...
# 973  Mining Breast Cancer Classification Rules from...
# 974  Identification of mammography anomalies for br...
# 975  Heterogeneity in Women&apos;s Adherence and It...
# 976  Diagnosis of breast cancer in light microscopi...
# 977  Assessing the acceptability and feasibility of...
# 978  Prognostic factor analysis for breast cancer u...
# 979  Integral strategy to supportive care in breast...
# 980  Characterization of Promiscuous Binding of Pho...
# 981  Breast cancer detection using MRF-based probab...
# 982  Feature Subset Selection and Typical Testors A...
# 983  One Step Assembly of Thin Films of Carbon Nano...
# 984  Automatic cell nuclei segmentation and classif...
# 985  Diagnosing breast cancer with an improved arti...
# 986  A Dataset for Breast Cancer Histopathological ...
# 987  Breast Cancer Symptom Clusters Derived From So...
# 988  Using Contextual Learning to Improve Diagnosti...
# 989  Stacked Sparse Autoencoder (SSAE) for Nuclei D...
# 990  AggNet - Deep Learning From Crowds for Mitosis...
# 991  A Compressive Sensing Approach for 3D Breast C...
# 992  Computer Aided Theragnosis Using Quantitative ...
# 993  Triaging Diagnostically Relevant Regions from ...
# 994  ConfidentCare - A Clinical Decision Support Sy...
# 995  Search and Breast Cancer - On Episodic Shifts ...
# 996  Mitosis Detection in Breast Cancer Histology I...
# 997  Medical Diagnostic System Basing Fuzzy Rough N...
# 998  A robust platform-independent gene signature f...
# 999  Data Driven Approach to Burden of Treatment Me...
#
#                           info_type  \
# 0                  Books and Theses
# 1                  Journal Articles
# 2                  Journal Articles
# 3    Conference and Workshop Papers
# 4             Informal Publications
# 5    Conference and Workshop Papers
# 6                  Journal Articles
# 7    Conference and Workshop Papers
# 8    Conference and Workshop Papers
# 9    Conference and Workshop Papers
# 10                 Books and Theses
# 11   Conference and Workshop Papers
# 12                 Books and Theses
# 13   Conference and Workshop Papers
# 14                 Journal Articles
# 15                 Journal Articles
# 16                 Journal Articles
# 17                 Journal Articles
# 18                 Journal Articles
# 19                 Journal Articles
# 20                 Journal Articles
# 21   Conference and Workshop Papers
# 22   Conference and Workshop Papers
# 23   Conference and Workshop Papers
# 24   Conference and Workshop Papers
# 25   Conference and Workshop Papers
# 26   Conference and Workshop Papers
# 27            Informal Publications
# 28            Informal Publications
# 29            Informal Publications
# ..                              ...
# 970                Journal Articles
# 971                Journal Articles
# 972                Journal Articles
# 973                Journal Articles
# 974                Journal Articles
# 975                Journal Articles
# 976                Journal Articles
# 977                Journal Articles
# 978                Journal Articles
# 979                Journal Articles
# 980                Journal Articles
# 981                Journal Articles
# 982                Journal Articles
# 983                Journal Articles
# 984                Journal Articles
# 985                Journal Articles
# 986                Journal Articles
# 987                Journal Articles
# 988                Journal Articles
# 989                Journal Articles
# 990                Journal Articles
# 991                Journal Articles
# 992                Journal Articles
# 993                Journal Articles
# 994                Journal Articles
# 995                Journal Articles
# 996  Conference and Workshop Papers
# 997  Conference and Workshop Papers
# 998  Conference and Workshop Papers
# 999  Conference and Workshop Papers
#
#                                               info_url  \
# 0              https://dblp.org/rec/phd/hal/Perrier18a
# 1      https://dblp.org/rec/journals/bmcmi/YeomCKCSC19
# 2     https://dblp.org/rec/journals/tbe/SongSMKSOAOK19
# 3        https://dblp.org/rec/conf/isat/LeszczynskiJ19
# 4    https://dblp.org/rec/journals/corr/abs-1905-10841
# 5              https://dblp.org/rec/conf/bmei/SunWFL17
# 6      https://dblp.org/rec/journals/cmpb/CardosoCOG16
# 7             https://dblp.org/rec/conf/bhi/BurrielP14
# 8         https://dblp.org/rec/conf/gecco/WinklerASS14
# 9          https://dblp.org/rec/conf/gecco/WinklerAS13
# 10         https://dblp.org/rec/phd/hal/Cheikhrouhou12
# 11       https://dblp.org/rec/conf/biostec/CasaliMBB12
# 12   https://dblp.org/rec/series/synthesis/2011Guliato
# 13        https://dblp.org/rec/conf/gecco/WinklerAJS11
# 14      https://dblp.org/rec/journals/fgcs/KhanIJDKF19
# 15   https://dblp.org/rec/journals/ijmi/Hartmann-Jo...
# 16          https://dblp.org/rec/journals/ijon/GuoSL19
# 17   https://dblp.org/rec/journals/jbi/ShamsizadehGR19
# 18   https://dblp.org/rec/journals/midm/StegeWHHDKR...
# 19     https://dblp.org/rec/journals/tmi/SamalaCHHRC19
# 20       https://dblp.org/rec/journals/vc/SathishKPK19
# 21         https://dblp.org/rec/conf/bcb/GandhiLSZH019
# 22   https://dblp.org/rec/conf/bnaic/BrahimetajPTCWM19
# 23           https://dblp.org/rec/conf/embc/YangWCLL19
# 24         https://dblp.org/rec/conf/isbi/NaylorBLR019
# 25     https://dblp.org/rec/conf/micad/DrukkerEEDPKG19
# 26       https://dblp.org/rec/conf/micad/NebbiaMCZZW19
# 27   https://dblp.org/rec/journals/corr/abs-1901-05958
# 28   https://dblp.org/rec/journals/corr/abs-1903-01854
# 29   https://dblp.org/rec/journals/corr/abs-1911-00036
# ..                                                 ...
# 970    https://dblp.org/rec/journals/jmlr/FanWYPLOPB16
# 971          https://dblp.org/rec/journals/jms/DizMF16
# 972         https://dblp.org/rec/journals/jms/SinghU16
# 973         https://dblp.org/rec/journals/jois/YehCW16
# 974    https://dblp.org/rec/journals/kbs/MagnaCJSMMN16
# 975     https://dblp.org/rec/journals/mansci/AyerASB16
# 976     https://dblp.org/rec/journals/mbec/KorkmazKP16
# 977      https://dblp.org/rec/journals/midm/AlamEPGD16
# 978          https://dblp.org/rec/journals/midm/JoeN16
# 979  https://dblp.org/rec/journals/midm/Lozano-Loza...
# 980     https://dblp.org/rec/journals/ploscb/YouHKNC16
# 981     https://dblp.org/rec/journals/pr/RastghalamP16
# 982    https://dblp.org/rec/journals/rcs/GallegosTAS16
# 983  https://dblp.org/rec/journals/sensors/NawazRCN...
# 984    https://dblp.org/rec/journals/sigpro/WangHLLZ16
# 985  https://dblp.org/rec/journals/soco/SaybaniWASKB16
# 986     https://dblp.org/rec/journals/tbe/SpanholOPH16
# 987      https://dblp.org/rec/journals/tcss/PingYMAI16
# 988       https://dblp.org/rec/journals/titb/SongHXS16
# 989     https://dblp.org/rec/journals/tmi/0005XLGWTM16
# 990  https://dblp.org/rec/journals/tmi/AlbarqouniBA...
# 991      https://dblp.org/rec/journals/tmi/BevacquaS16
# 992    https://dblp.org/rec/journals/tmi/GangehTSSTC16
# 993    https://dblp.org/rec/journals/tmi/PeikariGZCM16
# 994        https://dblp.org/rec/journals/tmm/AlaaMHS16
# 995        https://dblp.org/rec/journals/tweb/PaulWH16
# 996          https://dblp.org/rec/conf/aaai/0011DWQH16
# 997             https://dblp.org/rec/conf/aisi/Gafar16
# 998         https://dblp.org/rec/conf/amcc/MisganawV16
# 999            https://dblp.org/rec/conf/amia/ChengL16
#
#                                      info_venue  \
# 0                                           NaN
# 1                           BMC Medical Imaging
# 2               IEEE Trans. Biomed. Engineering
# 3                                          ISAT
# 4                                          CoRR
# 5                                     CISP-BMEI
# 6              Comput. Methods Programs Biomed.
# 7                                           BHI
# 8                                         GECCO
# 9                                         GECCO
# 10                                          NaN
# 11                                   BIODEVICES
# 12                                          NaN
# 13                                        GECCO
# 14                  Future Gener. Comput. Syst.
# 15                  Int. J. Medical Informatics
# 16                               Neurocomputing
# 17                       J. Biomed. Informatics
# 18          BMC Med. Inf. &amp; Decision Making
# 19                     IEEE Trans. Med. Imaging
# 20                          The Visual Computer
# 21                                          BCB
# 22                              BNAIC/BENELEARN
# 23                                         EMBC
# 24                                         ISBI
# 25   Medical Imaging - Computer-Aided Diagnosis
# 26   Medical Imaging - Computer-Aided Diagnosis
# 27                                         CoRR
# 28                                         CoRR
# 29                                         CoRR
# ..                                          ...
# 970                        J. Mach. Learn. Res.
# 971                          J. Medical Systems
# 972                          J. Medical Systems
# 973                      J. Intelligent Systems
# 974                          Knowl.-Based Syst.
# 975                          Management Science
# 976        Med. Biol. Engineering and Computing
# 977         BMC Med. Inf. &amp; Decision Making
# 978         BMC Med. Inf. &amp; Decision Making
# 979         BMC Med. Inf. &amp; Decision Making
# 980                  PLoS Computational Biology
# 981                           Pattern Recognit.
# 982               Research in Computing Science
# 983                                     Sensors
# 984                             Signal Process.
# 985                                Soft Comput.
# 986             IEEE Trans. Biomed. Engineering
# 987          IEEE Trans. Comput. Social Systems
# 988   IEEE J. Biomedical and Health Informatics
# 989                    IEEE Trans. Med. Imaging
# 990                    IEEE Trans. Med. Imaging
# 991                    IEEE Trans. Med. Imaging
# 992                    IEEE Trans. Med. Imaging
# 993                    IEEE Trans. Med. Imaging
# 994                      IEEE Trans. Multimedia
# 995                                        TWEB
# 996                                        AAAI
# 997                                        AISI
# 998                                         ACC
# 999                                        AMIA
#
#                                           info_venue_0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12   Modeling and Analysis of Shape with Applicatio...
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 970                                                NaN
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
# 976                                                NaN
# 977                                                NaN
# 978                                                NaN
# 979                                                NaN
# 980                                                NaN
# 981                                                NaN
# 982                                                NaN
# 983                                                NaN
# 984                                                NaN
# 985                                                NaN
# 986                                                NaN
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
# 991                                                NaN
# 992                                                NaN
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                      info_venue_1     info_volume info_year  \
# 0                                             NaN             NaN      2018
# 1                                             NaN              19      2019
# 2                                             NaN              66      2019
# 3                                             NaN             NaN      2019
# 4                                             NaN  abs/1905.10841      2019
# 5                                             NaN             NaN      2017
# 6                                             NaN             126      2016
# 7                                             NaN             NaN      2014
# 8                                             NaN             NaN      2014
# 9                                             NaN             NaN      2013
# 10                                            NaN             NaN      2012
# 11                                            NaN             NaN      2012
# 12   Synthesis Lectures on Biomedical Engineering             NaN      2011
# 13                                            NaN             NaN      2011
# 14                                            NaN              98      2019
# 15                                            NaN             125      2019
# 16                                            NaN             324      2019
# 17                                            NaN              94      2019
# 18                                            NaN              19      2019
# 19                                            NaN              38      2019
# 20                                            NaN              35      2019
# 21                                            NaN             NaN      2019
# 22                                            NaN             NaN      2019
# 23                                            NaN             NaN      2019
# 24                                            NaN             NaN      2019
# 25                                            NaN             NaN      2019
# 26                                            NaN             NaN      2019
# 27                                            NaN  abs/1901.05958      2019
# 28                                            NaN  abs/1903.01854      2019
# 29                                            NaN  abs/1911.00036      2019
# ..                                            ...             ...       ...
# 970                                           NaN              17      2016
# 971                                           NaN              40      2016
# 972                                           NaN              40      2016
# 973                                           NaN              25      2016
# 974                                           NaN             101      2016
# 975                                           NaN              62      2016
# 976                                           NaN              54      2016
# 977                                           NaN              16      2016
# 978                                           NaN              16      2016
# 979                                           NaN              16      2016
# 980                                           NaN              12      2016
# 981                                           NaN              51      2016
# 982                                           NaN             121      2016
# 983                                           NaN              16      2016
# 984                                           NaN             122      2016
# 985                                           NaN              20      2016
# 986                                           NaN              63      2016
# 987                                           NaN               3      2016
# 988                                           NaN              20      2016
# 989                                           NaN              35      2016
# 990                                           NaN              35      2016
# 991                                           NaN              35      2016
# 992                                           NaN              35      2016
# 993                                           NaN              35      2016
# 994                                           NaN              18      2016
# 995                                           NaN              10      2016
# 996                                           NaN             NaN      2016
# 997                                           NaN             NaN      2016
# 998                                           NaN             NaN      2016
# 999                                           NaN             NaN      2016
#
#              url
# 0     URL#388703
# 1      URL#59140
# 2     URL#159453
# 3     URL#271032
# 4     URL#348056
# 5     URL#878013
# 6    URL#1077541
# 7    URL#1768787
# 8    URL#1805847
# 9    URL#2082384
# 10   URL#2204726
# 11   URL#2313708
# 12   URL#2462011
# 13   URL#2595928
# 14     URL#82915
# 15     URL#96751
# 16     URL#97997
# 17    URL#108623
# 18    URL#125541
# 19    URL#171060
# 20    URL#177881
# 21    URL#193472
# 22    URL#196437
# 23    URL#219475
# 24    URL#271321
# 25    URL#285444
# 26    URL#285503
# 27    URL#330425
# 28    URL#336372
# 29    URL#373651
# ..           ...
# 970  URL#1121600
# 971  URL#1121887
# 972  URL#1122050
# 973  URL#1123128
# 974  URL#1127540
# 975  URL#1129184
# 976  URL#1129466
# 977  URL#1130174
# 978  URL#1130230
# 979  URL#1130250
# 980  URL#1138738
# 981  URL#1139503
# 982  URL#1141575
# 983  URL#1146530
# 984  URL#1149557
# 985  URL#1150897
# 986  URL#1155163
# 987  URL#1157487
# 988  URL#1162486
# 989  URL#1163769
# 990  URL#1163771
# 991  URL#1163793
# 992  URL#1163830
# 993  URL#1163915
# 994  URL#1164011
# 995  URL#1169852
# 996  URL#1174004
# 997  URL#1178918
# 998  URL#1180244
# 999  URL#1181468
#
# [1000 rows x 91 columns]

# %%
    processed_data = []
    header = []

# %%
    item = data_to_be_processed[3]
    reduced_item = {}

# %%
key ='result'
value= item

# %%
type(value) is list
# Out:
# False

# %%
    if type(value) is list:
        i = 0
        for sub_item in value:
            reduce_item(key + '_' + to_string(i), sub_item)
            i = i + 1
# Out:
# {'@score': '4',
#  '@id': '271032',
#  'info': {'authors': {'author': [{'@pid': '249/6174',
#      'text': 'Zbigniew Leszczynski'},
#     {'@pid': '249/6179', 'text': 'Tomasz Jasinski'}]},
#   'title': 'Artificial Neural Networks in Forecasting Cancer Therapy Methods and Costs of Cancer Patient Treatment. Case Study for Breast Cancer.',
#   'venue': 'ISAT',
#   'pages': '111-120',
#   'year': '2019',
#   'type': 'Conference and Workshop Papers',
#   'key': 'conf/isat/LeszczynskiJ19',
#   'doi': '10.1007/978-3-030-30443-0_10',
#   'ee': 'https://doi.org/10.1007/978-3-030-30443-0_10',
#   'url': 'https://dblp.org/rec/conf/isat/LeszczynskiJ19'},
#  'url': 'URL#271032'}

# %%
def JSON_to_CSV(inputdir, outputfile):
    # Reading arguments
    node = 'result'
    json_file_path = inputdir
    csv_file_path = outputfile

    fp = open(json_file_path, 'r')
    json_value = fp.read()
    raw_data = json.loads(json_value)
    fp.close()

    data_to_be_processed = raw_data[node]['hits']['hit']


    processed_data = []
    header = []
    for item in data_to_be_processed:
        reduced_item = {}
        reduce_item(node, item)

        header += reduced_item.keys()

        processed_data.append(reduced_item)

    header = list(set(header))
    header.sort()

    with open(csv_file_path, 'w+') as f:
        writer = csv.DictWriter(f, header, quoting=csv.QUOTE_ALL)
        writer.writeheader()
        for row in processed_data:
            writer.writerow(row)

    print("Just completed writing csv file with %d columns" % len(header))

# %%
if __name__ == "__main__":
    inputdir = input_default_path
    # Assign output file for output CSV
    if not os.path.exists(tmp_path):
        os.makedirs(tmp_path)
        print(f"[INFO] Created a new folder {tmp_path}")
    # Evaluation output file config
    head, tail = os.path.split(inputdir)
    tail = '.'.join((tail.split('.')[0], 'csv'))
    outputfile = f"{head}/{tail}"
    print(outputfile)
    if os.path.exists(outputfile):
        os.remove(outputfile)
        print(f"{outputfile} file removed")
    # Run CSV to json
    JSON_to_CSV(inputdir, outputfile)
